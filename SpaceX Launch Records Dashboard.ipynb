# %%
# !pip install "jupyterlab>=1.0" jupyterlab-dash==0.1.0a3
# !pip install --upgrade dash dash-core-components dash-html-components dash-renderer
# !pip install jupyter-dash
# Out:
# Requirement already satisfied: jupyterlab>=1.0 in /opt/anaconda3/lib/python3.7/site-packages (1.1.4)
# Requirement already satisfied: jupyterlab-dash==0.1.0a3 in /opt/anaconda3/lib/python3.7/site-packages (0.1.0a3)
# Requirement already satisfied: notebook>=4.3.1 in /opt/anaconda3/lib/python3.7/site-packages (from jupyterlab>=1.0) (6.0.1)
# Requirement already satisfied: tornado!=6.0.0,!=6.0.1,!=6.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from jupyterlab>=1.0) (6.0.3)
# Requirement already satisfied: jupyterlab_server~=1.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from jupyterlab>=1.0) (1.0.6)
# Requirement already satisfied: jinja2>=2.10 in /opt/anaconda3/lib/python3.7/site-packages (from jupyterlab>=1.0) (2.10.3)
# Requirement already satisfied: dash in /opt/anaconda3/lib/python3.7/site-packages (from jupyterlab-dash==0.1.0a3) (2.0.0)
# Requirement already satisfied: jupyter-server-proxy in /opt/anaconda3/lib/python3.7/site-packages (from jupyterlab-dash==0.1.0a3) (3.1.0)
# Requirement already satisfied: nbconvert in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (5.6.0)
# Requirement already satisfied: Send2Trash in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (0.8.2)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (18.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (4.3.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (4.5.0)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (0.7.1)
# Requirement already satisfied: jupyter-client>=5.3.1 in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (5.3.3)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (5.1.2)
# Requirement already satisfied: nbformat in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.3.1->jupyterlab>=1.0) (4.4.0)
# Requirement already satisfied: json5 in /opt/anaconda3/lib/python3.7/site-packages (from jupyterlab_server~=1.0.0->jupyterlab>=1.0) (0.8.5)
# Requirement already satisfied: jsonschema>=3.0.1 in /opt/anaconda3/lib/python3.7/site-packages (from jupyterlab_server~=1.0.0->jupyterlab>=1.0) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.7/site-packages (from jinja2>=2.10->jupyterlab>=1.0) (1.1.1)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (1.1.1)
# Requirement already satisfied: dash-table==5.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (5.0.0)
# Requirement already satisfied: flask-compress in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (1.10.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyterlab-dash==0.1.0a3) (5.3.1)
# Requirement already satisfied: jupyter-server>=1.0 in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (1.11.0)
# Requirement already satisfied: simpervisor>=0.4 in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (0.4)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (3.7.4.post0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab>=1.0) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab>=1.0) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab>=1.0) (1.4.2)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab>=1.0) (0.6.0)
# Requirement already satisfied: bleach in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab>=1.0) (3.1.0)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab>=1.0) (2.4.2)
# Requirement already satisfied: testpath in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab>=1.0) (0.4.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2.1->notebook>=4.3.1->jupyterlab>=1.0) (1.12.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2.1->notebook>=4.3.1->jupyterlab>=1.0) (4.4.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-client>=5.3.1->notebook>=4.3.1->jupyterlab>=1.0) (2.8.0)
# Requirement already satisfied: ipython>=5.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (7.8.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab_server~=1.0.0->jupyterlab>=1.0) (0.15.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab_server~=1.0.0->jupyterlab>=1.0) (41.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab_server~=1.0.0->jupyterlab>=1.0) (19.2.0)
# Requirement already satisfied: click>=5.1 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.4->dash->jupyterlab-dash==0.1.0a3) (7.0)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.4->dash->jupyterlab-dash==0.1.0a3) (0.16.0)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.4->dash->jupyterlab-dash==0.1.0a3) (1.1.0)
# Requirement already satisfied: brotli in /opt/anaconda3/lib/python3.7/site-packages (from flask-compress->dash->jupyterlab-dash==0.1.0a3) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from plotly>=5.0.0->dash->jupyterlab-dash==0.1.0a3) (8.0.1)
# Requirement already satisfied: websocket-client in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (1.2.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (3.3.1)
# Requirement already satisfied: argon2-cffi in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (21.1.0)
# Requirement already satisfied: requests-unixsocket in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.5 in /opt/anaconda3/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (3.10.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (5.1.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /opt/anaconda3/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (3.0.1)
# Requirement already satisfied: chardet<5.0,>=2.0 in /opt/anaconda3/lib/python3.7/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (3.0.4)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.3.1->jupyterlab>=1.0) (0.5.1)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (0.1.0)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (4.7.0)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (0.15.1)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (2.0.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (2.8)
# Requirement already satisfied: cffi>=1.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (1.12.3)
# Requirement already satisfied: requests>=1.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests-unixsocket->jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (2.22.0)
# Requirement already satisfied: urllib3>=1.8 in /opt/anaconda3/lib/python3.7/site-packages (from requests-unixsocket->jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (1.24.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (0.6.0)
# Requirement already satisfied: parso>=0.5.0 in /opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (0.5.1)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=4.3.1->jupyterlab>=1.0) (0.1.7)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (2.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=1.1->requests-unixsocket->jupyter-server>=1.0->jupyter-server-proxy->jupyterlab-dash==0.1.0a3) (2019.9.11)
# Requirement already up-to-date: dash in /opt/anaconda3/lib/python3.7/site-packages (2.0.0)
# Requirement already up-to-date: dash-core-components in /opt/anaconda3/lib/python3.7/site-packages (2.0.0)
# Requirement already up-to-date: dash-html-components in /opt/anaconda3/lib/python3.7/site-packages (2.0.0)
# Requirement already up-to-date: dash-renderer in /opt/anaconda3/lib/python3.7/site-packages (1.9.1)
# Requirement already satisfied, skipping upgrade: flask-compress in /opt/anaconda3/lib/python3.7/site-packages (from dash) (1.10.1)
# Requirement already satisfied, skipping upgrade: dash-table==5.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash) (5.0.0)
# Requirement already satisfied, skipping upgrade: plotly>=5.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash) (5.3.1)
# Requirement already satisfied, skipping upgrade: Flask>=1.0.4 in /opt/anaconda3/lib/python3.7/site-packages (from dash) (1.1.1)
# Requirement already satisfied, skipping upgrade: brotli in /opt/anaconda3/lib/python3.7/site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied, skipping upgrade: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied, skipping upgrade: six in /opt/anaconda3/lib/python3.7/site-packages (from plotly>=5.0.0->dash) (1.12.0)
# Requirement already satisfied, skipping upgrade: Jinja2>=2.10.1 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.4->dash) (2.10.3)
# Requirement already satisfied, skipping upgrade: Werkzeug>=0.15 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.4->dash) (0.16.0)
# Requirement already satisfied, skipping upgrade: itsdangerous>=0.24 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied, skipping upgrade: click>=5.1 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.4->dash) (7.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Requirement already satisfied: jupyter-dash in /opt/anaconda3/lib/python3.7/site-packages (0.4.0)
# Requirement already satisfied: ipython in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (7.8.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (2.22.0)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (5.1.2)
# Requirement already satisfied: ansi2html in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: dash in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (2.0.0)
# Requirement already satisfied: retrying in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: flask in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (1.1.1)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.15.1)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (41.4.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (4.7.0)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (4.3.3)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.1.0)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (2.4.2)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (2.0.10)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (4.4.0)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests->jupyter-dash) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests->jupyter-dash) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests->jupyter-dash) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests->jupyter-dash) (1.24.2)
# Requirement already satisfied: jupyter-client in /opt/anaconda3/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (5.3.3)
# Requirement already satisfied: tornado>=4.2 in /opt/anaconda3/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (6.0.3)
# Requirement already satisfied: plotly>=5.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyter-dash) (5.3.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: flask-compress in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyter-dash) (1.10.1)
# Requirement already satisfied: dash-table==5.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: six>=1.7.0 in /opt/anaconda3/lib/python3.7/site-packages (from retrying->jupyter-dash) (1.12.0)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/anaconda3/lib/python3.7/site-packages (from flask->jupyter-dash) (0.16.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/anaconda3/lib/python3.7/site-packages (from flask->jupyter-dash) (2.10.3)
# Requirement already satisfied: click>=5.1 in /opt/anaconda3/lib/python3.7/site-packages (from flask->jupyter-dash) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda3/lib/python3.7/site-packages (from flask->jupyter-dash) (1.1.0)
# Requirement already satisfied: parso>=0.5.0 in /opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython->jupyter-dash) (0.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython->jupyter-dash) (0.6.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2->ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->jupyter-dash) (0.1.7)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash) (2.8.0)
# Requirement already satisfied: pyzmq>=13 in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash) (18.1.0)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash) (4.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: brotli in /opt/anaconda3/lib/python3.7/site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (1.1.1)

# %%
# Import required libraries
import pandas as pd
import dash
from dash import html as html
from dash import dcc as dcc
from dash.dependencies import Input, Output
import plotly.express as px

# %%
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                
                                dcc.Dropdown(id='site_dropdown',
                                             options=[{'label': 'All Sites', 'value': 'ALL'},{'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'}, 
                                                      {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},{'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}]
                                             ,placeholder='Select a Launch Site here', searchable = True , value = 'All Sites'),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(
                                    id='payload_slider',
                                    min=0,
                                    max=10000,
                                    step=1000,  
                                    marks = {
                                            0: '0 kg',
                                            1000: '1000 kg',
                                            2000: '2000 kg',
                                            3000: '3000 kg',
                                            4000: '4000 kg',
                                            5000: '5000 kg',
                                            6000: '6000 kg',  
                                            7000: '7000 kg',
                                            8000: '8000 kg',
                                            9000: '9000 kg',
                                            10000: '10000 kg'                                         
                                    },

                                    value=[min_payload,max_payload]
                                ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(
     Output(component_id='success-pie-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value')])

def get_pie_chart(site_dropdown):
    if (site_dropdown == 'All Sites'):
        df  = spacex_df[spacex_df['class'] == 1]
        fig = px.pie(df, names = 'Launch Site',hole=.3,title = 'Total Success Launches By all sites')
    else:
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        fig = px.pie(df, names = 'class',hole=.3,title = 'Total Success Launches for site '+site_dropdown)
    return fig


# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(
     Output(component_id='success-payload-scatter-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value'),Input(component_id="payload_slider", component_property="value")]               
)
def get_scattergraph(site_dropdown,payload_slider):
    if site_dropdown == 'All Sites':
        low, high = payload_slider
        df  = spacex_df
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class", 
            color="Booster Version",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    else:
        low, high = payload_slider
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class", title = 'correlation between Payload and Success for'+site_dropdown,
            color="Booster Version"
            ,size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Sep/2021 00:23:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2021 00:23:27] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2021 00:23:27] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2021 00:23:27] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2021 00:23:27] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2021 00:23:27] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2021 00:23:27] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2021 00:23:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2021 00:23:28] "POST /_dash-update-component HTTP/1.1" 200 -
